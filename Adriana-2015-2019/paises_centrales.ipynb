# %%
import spotipy

from spotipy.oauth2 import SpotifyClientCredentials

# %%
import pandas as pd
import requests

# %%
# Coloca tus credenciales aquí
CLIENT_ID = ''
CLIENT_SECRET = ''
# Autenticación
auth_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
# Coloca tus credenciales de lastfm aquí
SHARED_SECRET = ''
API_KEY = ' '

last_fm_connect = requests.get(f"http://www.last.fm/api/auth/?api_key={API_KEY}")

# %%
paises_europa_central = {
    "AT": "Austria",
    "DE": "Alemania",
    "CH": "Suiza",
    "LI": "Liechtenstein",
    "BE": "Bélgica",
    "LU": "Luxemburgo",
    "NL": "Países Bajos"}

# %%
def extraccion_por_paises(diccionario_zonas, años):
    todos_los_datos = [] # Esto es una lista de dicts donde se van guardando los diccionarios de cada país
    for pais in diccionario_zonas.keys():
        datos_rango = sp.search(q = f'year:{años}', limit=50, offset=0, type='track', market={pais}) # Cada una tiene que cambiar en q el rango de años
        datos_por_pais = {}
        datos_por_pais['pais'] = pais
        datos_por_pais['datos'] = datos_rango
        todos_los_datos.append(datos_por_pais)
    return todos_los_datos

# %%
def filtro_de_datos(lista_datos_zonas, datos):
    for datos_pais in lista_datos_zonas:
        for element in datos_pais['datos']['tracks']['items']:
            datos['pais'].append(datos_pais['pais'])
            datos['popularity'].append(element['popularity'])
            datos['nombre'].append(element['name'])
            artistas = []
            for artista in element['artists']:
                artistas.append(artista['name'])   
            artistas_str = ', '.join(artistas)
            datos['artista'].append(artistas_str)

# %%
p_central = extraccion_por_paises(paises_europa_central, '2015-2019')

# %%
dic_central = {'nombre': [], 'popularity': [], 'artista': [], 'pais': [], 'genero': []}

# %%
filtro_de_datos(p_central, dic_central)

# %%
dic_central
# Out:
# {'nombre': ['All The Stars (with SZA)',
#   'Say You Love Me (Live at Ziggo Dome, Amsterdam)',
#   'The Night We Met',
#   'Liebe Grüße (mit Fatoni)',
#   'Neymar',
#   "I'm Better (feat. Lamb)",
#   'Swim',
#   'Matador (feat. Tommy)',
#   'Softcore',
#   'Holding Back the Years (Live at Ziggo Dome, Amsterdam)',
#   'HIGHEST IN THE ROOM',
#   'Enamorado',
#   'Hauseingang',
#   "Greenwood, Philip Selway, Edward O'Brien, Colin Greenwood: Pyramid Song (Arr. Lawson)",
#   'Ohne mein Team',
#   'So Beautiful (Live at Ziggo Dome, Amsterdam)',
#   'HUMBLE.',
#   "Durch die schweren Zeiten (I'll Carry You) [feat. Angus & Julia Stone] [MTV Unplugged 2] - Live vom Atlantik 2018",
#   'See You Again (feat. Kali Uchis)',
#   'Your Mirror (Live at Ziggo Dome, Amsterdam)',
#   'Something Just Like This',
#   'A New Flame (Live at Ziggo Dome, Amsterdam)',
#   'Lush Life',
#   'Pakete',
#   'Falling Down - Bonus Track',
#   'Слэмятся пацаны',
#   "Where's My Love",
#   'For Your Babies (Live at Ziggo Dome, Amsterdam)',
#   'lovely (with Khalid)',
#   'Stretch',
#   'Auffe aufn Berg',
#   'Someday in My Life (Live at Ziggo Dome, Amsterdam)',
#   'Lucid Dreams',
#   'Sirenen',
#   'Cruel Summer',
#   'Wenn jetzt Sommer wär (feat. Chapeau Claque)',
#   'Daddy Issues',
#   'Hate to Love (feat. Jamie T)',
#   'Evergreen',
#   'Medusa',
#   'Revenge',
#   'Full Automatic (feat. Diego)',
#   'Unforgettable',
#   'Did You Love Me',
#   'Without You (feat. Sandro Cavazza)',
#   'Дождь (feat. МакSим)',
#   'Starboy',
#   'O secunda',
#   'goosebumps',
#   'Happy End',
#   'All The Stars (with SZA)',
#   'Matador (feat. Tommy)',
#   'Babyschlaf mit Meeresrauschen',
#   'Дождь (feat. МакSим)',
#   'Nie mehr Fastelovend',
#   'Liebe Grüße (mit Fatoni)',
#   'The Night We Met',
#   'Слэмятся пацаны',
#   'Swim',
#   "I'm Better (feat. Lamb)",
#   'Guten Morgen Barbarossaplatz',
#   'Sirenen',
#   'Neymar',
#   'Wenn jetzt Sommer wär (feat. Chapeau Claque)',
#   'Hauseingang',
#   'Holding Back the Years (Live at Ziggo Dome, Amsterdam)',
#   'Softcore',
#   "Greenwood, Philip Selway, Edward O'Brien, Colin Greenwood: Pyramid Song (Arr. Lawson)",
#   'Lucid Dreams',
#   'Pakete',
#   'Falling Down - Bonus Track',
#   'Enamorado',
#   'HUMBLE.',
#   'Stronger Together',
#   "Where's My Love",
#   'So Beautiful (Live at Ziggo Dome, Amsterdam)',
#   'lovely (with Khalid)',
#   'Say You Love Me (Live at Ziggo Dome, Amsterdam)',
#   'Ohne mein Team',
#   'Kapitel 1 / Frühling',
#   'HIGHEST IN THE ROOM',
#   'For Your Babies (Live at Ziggo Dome, Amsterdam)',
#   'Lush Life',
#   'Happy End',
#   'Bye Bye',
#   'Your Mirror (Live at Ziggo Dome, Amsterdam)',
#   'Daddy Issues',
#   'Bester Sommer',
#   'See You Again (feat. Kali Uchis)',
#   'Hate to Love (feat. Jamie T)',
#   'Cruel Summer',
#   "Cliff's Edge",
#   'Unforgettable',
#   'Someday in My Life (Live at Ziggo Dome, Amsterdam)',
#   'Starboy',
#   'Medusa',
#   'Deutschland',
#   'A New Flame (Live at Ziggo Dome, Amsterdam)',
#   'Something Just Like This',
#   'Stretch',
#   'All The Stars (with SZA)',
#   'Enamorado',
#   'The Night We Met',
#   'Wenn jetzt Sommer wär (feat. Chapeau Claque)',
#   'Someone You Loved',
#   "I'm Better (feat. Lamb)",
#   'Believer',
#   'Liebe Grüße (mit Fatoni)',
#   'lovely (with Khalid)',
#   'Matador (feat. Tommy)',
#   'Something Just Like This',
#   'Holding Back the Years (Live at Ziggo Dome, Amsterdam)',
#   "Where's My Love",
#   'Дождь (feat. МакSим)',
#   'See You Again (feat. Kali Uchis)',
#   'A New Flame (Live at Ziggo Dome, Amsterdam)',
#   'Shape of You',
#   'Your Mirror (Live at Ziggo Dome, Amsterdam)',
#   'Perfect',
#   'For Your Babies (Live at Ziggo Dome, Amsterdam)',
#   "Est-ce que tu m'aimes ? - Pilule bleue",
#   'Someday in My Life (Live at Ziggo Dome, Amsterdam)',
#   'HIGHEST IN THE ROOM',
#   'Pakete',
#   'Ransom',
#   'Say You Love Me (Live at Ziggo Dome, Amsterdam)',
#   'Unforgettable',
#   'So Beautiful (Live at Ziggo Dome, Amsterdam)',
#   'Cruel Summer',
#   'Stretch',
#   'Always Remember Us This Way',
#   'Tabarnak',
#   'Starboy',
#   'Sirenen',
#   'Shallow',
#   "Greenwood, Philip Selway, Edward O'Brien, Colin Greenwood: Pyramid Song (Arr. Lawson)",
#   'Softcore',
#   'Skrrt',
#   'Swim',
#   'Слэмятся пацаны',
#   'Lush Life',
#   'Killing Me',
#   'HUMBLE.',
#   'Did You Love Me',
#   'Thunder',
#   '言葉のいらない約束',
#   'Low Life (feat. The Weeknd)',
#   'Cristo',
#   'goosebumps',
#   'Senza farlo apposta',
#   'All The Stars (with SZA)',
#   'Wenn jetzt Sommer wär (feat. Chapeau Claque)',
#   'See You Again (feat. Kali Uchis)',
#   'Downtown',
#   'The Night We Met',
#   'Skrrt',
#   'HUMBLE.',
#   "Greenwood, Philip Selway, Edward O'Brien, Colin Greenwood: Pyramid Song (Arr. Lawson)",
#   "That's What I Like",
#   'Holding Back the Years (Live at Ziggo Dome, Amsterdam)',
#   'Starboy',
#   "I'm Better (feat. Lamb)",
#   'Cruel Summer',
#   'Enamorado',
#   'Swim',
#   'Слэмятся пацаны',
#   'Something Just Like This',
#   'Say You Love Me (Live at Ziggo Dome, Amsterdam)',
#   'Perfect',
#   'For Your Babies (Live at Ziggo Dome, Amsterdam)',
#   'Shape of You',
#   'So Beautiful (Live at Ziggo Dome, Amsterdam)',
#   'Pink + White',
#   'Matador (feat. Tommy)',
#   'lovely (with Khalid)',
#   'Milion słów',
#   'Closer',
#   'Your Mirror (Live at Ziggo Dome, Amsterdam)',
#   'Believer',
#   'Дождь (feat. МакSим)',
#   'goosebumps',
#   'Someday in My Life (Live at Ziggo Dome, Amsterdam)',
#   'Dandelions',
#   'Ee Khalbitha (From "IDI")',
#   'White Ferrari',
#   'Stretch',
#   'Someone You Loved',
#   'A New Flame (Live at Ziggo Dome, Amsterdam)',
#   'One Dance',
#   'Die Heelal (feat. Early B)',
#   'Ransom',
#   'Sirenen',
#   'The Hills',
#   '言葉のいらない約束',
#   'Die For You',
#   'Do It Like You Mean It (feat. Yoel 905)',
#   'Best Part (feat. H.E.R.)',
#   'Pakete',
#   "There's Nothing Holdin' Me Back",
#   'Stronger Together',
#   'The Night We Met',
#   'Holding Back the Years (Live at Ziggo Dome, Amsterdam)',
#   'All The Stars (with SZA)',
#   "Greenwood, Philip Selway, Edward O'Brien, Colin Greenwood: Pyramid Song (Arr. Lawson)",
#   'lovely (with Khalid)',
#   'Enamorado',
#   'See You Again (feat. Kali Uchis)',
#   "I'm Better (feat. Lamb)",
#   'Someone You Loved',
#   'Слэмятся пацаны',
#   'Shallow',
#   'Your Mirror (Live at Ziggo Dome, Amsterdam)',
#   "when the party's over",
#   'So Beautiful (Live at Ziggo Dome, Amsterdam)',
#   'Sous la lune',
#   'Say You Love Me (Live at Ziggo Dome, Amsterdam)',
#   "La vie qu'on mène",
#   'Tabarnak',
#   'Lush Life',
#   'For Your Babies (Live at Ziggo Dome, Amsterdam)',
#   "Est-ce que tu m'aimes ? - Pilule bleue",
#   'Someday in My Life (Live at Ziggo Dome, Amsterdam)',
#   'Où aller',
#   'Wenn jetzt Sommer wär (feat. Chapeau Claque)',
#   'Vrais',
#   'A New Flame (Live at Ziggo Dome, Amsterdam)',
#   "Where's My Love",
#   "In Betweenin'",
#   'Always Remember Us This Way',
#   'Allez (feat. Leto)',
#   'Shape of You',
#   'Дождь (feat. МакSим)',
#   'Something Just Like This',
#   'Even Angels (feat. Blas Cantó)',
#   'Believer',
#   'Ee Khalbitha (From "IDI")',
#   'Putana',
#   'Skrrt',
#   'ocean eyes',
#   'Did You Love Me',
#   'Are You With Me',
#   "All I've Ever Known",
#   'Perfect',
#   'Slow Songs',
#   'HUMBLE.',
#   'Strangers With A Memory',
#   'Big Daddy Jok',
#   'Stretch',
#   'Swim',
#   'Downtown',
#   'All The Stars (with SZA)',
#   "Greenwood, Philip Selway, Edward O'Brien, Colin Greenwood: Pyramid Song (Arr. Lawson)",
#   'The Night We Met',
#   'A New Flame (Live at Ziggo Dome, Amsterdam)',
#   "La vie qu'on mène",
#   'Stretch',
#   'lovely (with Khalid)',
#   'Skrrt',
#   'See You Again (feat. Kali Uchis)',
#   'Matador (feat. Tommy)',
#   'Something Just Like This',
#   'Your Mirror (Live at Ziggo Dome, Amsterdam)',
#   'HUMBLE.',
#   'Enamorado',
#   "Est-ce que tu m'aimes ? - Pilule bleue",
#   'Holding Back the Years (Live at Ziggo Dome, Amsterdam)',
#   'Someone You Loved',
#   'Wenn jetzt Sommer wär (feat. Chapeau Claque)',
#   'HIGHEST IN THE ROOM',
#   'For Your Babies (Live at Ziggo Dome, Amsterdam)',
#   'Cruel Summer',
#   'Downtown',
#   'Believer',
#   "I'm Better (feat. Lamb)",
#   'goosebumps',
#   'Слэмятся пацаны',
#   'Shape of You',
#   'Say You Love Me (Live at Ziggo Dome, Amsterdam)',
#   'Unforgettable',
#   'So Beautiful (Live at Ziggo Dome, Amsterdam)',
#   'Où aller',
#   'Milion słów',
#   'Starboy',
#   'Дождь (feat. МакSим)',
#   'Swim',
#   'Someday in My Life (Live at Ziggo Dome, Amsterdam)',
#   'Ransom',
#   'Ee Khalbitha (From "IDI")',
#   'Vrais',
#   'Die Heelal (feat. Early B)',
#   'Always Remember Us This Way',
#   'Sirenen',
#   'Shallow',
#   '言葉のいらない約束',
#   'Perfect',
#   'Do It Like You Mean It (feat. Yoel 905)',
#   'Pink + White',
#   'Pakete',
#   'Lucid Dreams',
#   'Stronger Together',
#   'All The Stars (with SZA)',
#   "Greenwood, Philip Selway, Edward O'Brien, Colin Greenwood: Pyramid Song (Arr. Lawson)",
#   'The Night We Met',
#   'Holding Back the Years (Live at Ziggo Dome, Amsterdam)',
#   'See You Again (feat. Kali Uchis)',
#   "I'm Better (feat. Lamb)",
#   'lovely (with Khalid)',
#   'So Beautiful (Live at Ziggo Dome, Amsterdam)',
#   'Jungle',
#   'Say You Love Me (Live at Ziggo Dome, Amsterdam)',
#   'Lush Life',
#   'Enamorado',
#   'Duurt Te Lang',
#   'Your Mirror (Live at Ziggo Dome, Amsterdam)',
#   'Shallow',
#   'For Your Babies (Live at Ziggo Dome, Amsterdam)',
#   'Do Or Die',
#   'Someday in My Life (Live at Ziggo Dome, Amsterdam)',
#   'Always Remember Us This Way',
#   'God Is Gangsta',
#   'Someone You Loved',
#   'Слэмятся пацаны',
#   'Pink + White',
#   'A New Flame (Live at Ziggo Dome, Amsterdam)',
#   'Roller Coaster',
#   'Verdi: Il Trovatore - Tacea la notte placida',
#   "when the party's over",
#   'Wenn jetzt Sommer wär (feat. Chapeau Claque)',
#   'Without You (feat. Sandro Cavazza)',
#   'Downtown',
#   'Something Just Like This',
#   'In My Sleep (feat. King Kosa)',
#   'Investeren In De Liefde',
#   'Wake Up (A Fashion Film)',
#   'Energie',
#   'Gönlüm Ataşlara Yandı',
#   'This Town',
#   'Дождь (feat. МакSим)',
#   'Perfect',
#   'Cold Little Heart - Live Session',
#   'Love On The Brain',
#   'Milion słów',
#   'ocean eyes',
#   "In Betweenin'",
#   'Uptown Funk (feat. Bruno Mars)',
#   'Skrrt',
#   "Where's My Love",
#   'Die Heelal (feat. Early B)',
#   'Lovely Body',
#   'Arcade - 1 Mic 1 Take'],
#  'popularity': [90,
#   1,
#   85,
#   0,
#   63,
#   2,
#   83,
#   1,
#   81,
#   2,
#   80,
#   2,
#   63,
#   3,
#   62,
#   1,
#   84,
#   0,
#   86,
#   1,
#   83,
#   0,
#   77,
#   0,
#   79,
#   2,
#   76,
#   1,
#   83,
#   0,
#   60,
#   0,
#   81,
#   0,
#   84,
#   0,
#   81,
#   0,
#   78,
#   0,
#   79,
#   0,
#   81,
#   0,
#   77,
#   1,
#   84,
#   0,
#   81,
#   0,
#   90,
#   1,
#   67,
#   1,
#   66,
#   0,
#   85,
#   2,
#   83,
#   2,
#   62,
#   0,
#   63,
#   0,
#   63,
#   2,
#   81,
#   3,
#   81,
#   0,
#   79,
#   2,
#   84,
#   0,
#   76,
#   1,
#   83,
#   1,
#   62,
#   0,
#   80,
#   1,
#   77,
#   0,
#   61,
#   1,
#   81,
#   0,
#   86,
#   0,
#   84,
#   0,
#   81,
#   0,
#   84,
#   0,
#   71,
#   0,
#   83,
#   0,
#   90,
#   2,
#   85,
#   0,
#   81,
#   2,
#   81,
#   0,
#   83,
#   1,
#   83,
#   2,
#   76,
#   1,
#   86,
#   0,
#   83,
#   1,
#   83,
#   1,
#   71,
#   0,
#   80,
#   0,
#   81,
#   1,
#   81,
#   1,
#   84,
#   0,
#   79,
#   0,
#   84,
#   0,
#   79,
#   3,
#   81,
#   7,
#   83,
#   2,
#   77,
#   0,
#   84,
#   0,
#   80,
#   0,
#   80,
#   0,
#   81,
#   0,
#   90,
#   0,
#   86,
#   14,
#   85,
#   7,
#   84,
#   3,
#   84,
#   2,
#   84,
#   2,
#   84,
#   2,
#   83,
#   2,
#   83,
#   1,
#   83,
#   1,
#   83,
#   1,
#   83,
#   1,
#   83,
#   1,
#   82,
#   1,
#   81,
#   1,
#   81,
#   0,
#   81,
#   0,
#   81,
#   0,
#   81,
#   0,
#   81,
#   0,
#   81,
#   0,
#   81,
#   0,
#   81,
#   0,
#   81,
#   0,
#   81,
#   0,
#   85,
#   2,
#   90,
#   3,
#   83,
#   2,
#   86,
#   2,
#   81,
#   2,
#   79,
#   1,
#   80,
#   1,
#   70,
#   1,
#   68,
#   0,
#   77,
#   1,
#   71,
#   0,
#   55,
#   0,
#   68,
#   0,
#   76,
#   0,
#   79,
#   0,
#   83,
#   1,
#   83,
#   0,
#   81,
#   0,
#   67,
#   7,
#   79,
#   0,
#   75,
#   0,
#   83,
#   0,
#   84,
#   0,
#   66,
#   0,
#   83,
#   14,
#   90,
#   3,
#   85,
#   0,
#   68,
#   0,
#   83,
#   7,
#   86,
#   1,
#   83,
#   1,
#   84,
#   2,
#   71,
#   2,
#   81,
#   0,
#   80,
#   1,
#   84,
#   14,
#   81,
#   2,
#   81,
#   2,
#   83,
#   1,
#   81,
#   1,
#   55,
#   1,
#   84,
#   1,
#   83,
#   0,
#   81,
#   0,
#   68,
#   0,
#   79,
#   0,
#   79,
#   0,
#   83,
#   0,
#   83,
#   0,
#   81,
#   0,
#   90,
#   3,
#   85,
#   2,
#   86,
#   2,
#   83,
#   1,
#   55,
#   1,
#   77,
#   2,
#   54,
#   1,
#   79,
#   1,
#   55,
#   0,
#   79,
#   0,
#   81,
#   2,
#   83,
#   0,
#   54,
#   0,
#   80,
#   0,
#   77,
#   14,
#   83,
#   0,
#   54,
#   0,
#   54,
#   0,
#   74,
#   1,
#   83,
#   0,
#   81,
#   1,
#   79,
#   0,
#   81,
#   7,
#   76,
#   0,
#   53,
#   0],
#  'artista': ['Kendrick Lamar, SZA',
#   'Simply Red',
#   'Lord Huron',
#   'Antilopen Gang, Fatoni',
#   'Capital Bra, Ufo361',
#   'Missy Elliott, Lamb',
#   'Chase Atlantic',
#   'CAPO, Tommy',
#   'The Neighbourhood',
#   'Simply Red',
#   'Travis Scott',
#   'Alexander Stewart',
#   'Pashanim',
#   'Jonny Greenwood, Thom Yorke, Philip Selway, Edward O’Brien, Colin Greenwood, VOCES8, Thomas Gould, Matthew Sharp, Eleanor Turner',
#   'Bonez MC, RAF Camora, Maxwell',
#   'Simply Red',
#   'Kendrick Lamar',
#   'Udo Lindenberg, Angus & Julia Stone',
#   'Tyler, The Creator, Kali Uchis',
#   'Simply Red',
#   'The Chainsmokers, Coldplay',
#   'Simply Red',
#   'Zara Larsson',
#   'Tommy',
#   'Lil Peep, XXXTENTACION',
#   'Little Big, Ruki Vverh!',
#   'SYML',
#   'Simply Red',
#   'Billie Eilish, Khalid',
#   'Louise',
#   'Jägermeister DJ Alex, Matty Valentino',
#   'Simply Red',
#   'Juice WRLD',
#   'Tommy',
#   'Taylor Swift',
#   'Pretty Pink, Chapeau Claque',
#   'The Neighbourhood',
#   'Beatsteaks, Jamie T',
#   'Richy Mitch & The Coal Miners',
#   'Tommy',
#   'XXXTENTACION',
#   'Sleiman, Diego',
#   'French Montana, Swae Lee',
#   'Shannon & the Clams',
#   'Avicii, Sandro Cavazza',
#   'Geegun, MAKSIM',
#   'The Weeknd, Daft Punk',
#   'DJ Project, Giulia',
#   'Travis Scott',
#   'Lina Larissa Strahl',
#   'Kendrick Lamar, SZA',
#   'CAPO, Tommy',
#   'Weißes Rauschen HD',
#   'Geegun, MAKSIM',
#   'Querbeat',
#   'Antilopen Gang, Fatoni',
#   'Lord Huron',
#   'Little Big, Ruki Vverh!',
#   'Chase Atlantic',
#   'Missy Elliott, Lamb',
#   'Querbeat',
#   'Tommy',
#   'Capital Bra, Ufo361',
#   'Pretty Pink, Chapeau Claque',
#   'Pashanim',
#   'Simply Red',
#   'The Neighbourhood',
#   'Jonny Greenwood, Thom Yorke, Philip Selway, Edward O’Brien, Colin Greenwood, VOCES8, Thomas Gould, Matthew Sharp, Eleanor Turner',
#   'Juice WRLD',
#   'Tommy',
#   'Lil Peep, XXXTENTACION',
#   'Alexander Stewart',
#   'Kendrick Lamar',
#   'Paul van Dyk, Pierre Pienaar',
#   'SYML',
#   'Simply Red',
#   'Billie Eilish, Khalid',
#   'Simply Red',
#   'Bonez MC, RAF Camora, Maxwell',
#   'DLG',
#   'Travis Scott',
#   'Simply Red',
#   'Zara Larsson',
#   'Lina Larissa Strahl',
#   'CRO',
#   'Simply Red',
#   'The Neighbourhood',
#   'Lina Larissa Strahl',
#   'Tyler, The Creator, Kali Uchis',
#   'Beatsteaks, Jamie T',
#   'Taylor Swift',
#   'Hayley Kiyoko',
#   'French Montana, Swae Lee',
#   'Simply Red',
#   'The Weeknd, Daft Punk',
#   'Tommy',
#   'Rammstein',
#   'Simply Red',
#   'The Chainsmokers, Coldplay',
#   'Louise',
#   'Kendrick Lamar, SZA',
#   'Alexander Stewart',
#   'Lord Huron',
#   'Pretty Pink, Chapeau Claque',
#   'Lewis Capaldi',
#   'Missy Elliott, Lamb',
#   'Imagine Dragons',
#   'Antilopen Gang, Fatoni',
#   'Billie Eilish, Khalid',
#   'CAPO, Tommy',
#   'The Chainsmokers, Coldplay',
#   'Simply Red',
#   'SYML',
#   'Geegun, MAKSIM',
#   'Tyler, The Creator, Kali Uchis',
#   'Simply Red',
#   'Ed Sheeran',
#   'Simply Red',
#   'Ed Sheeran',
#   'Simply Red',
#   'GIMS',
#   'Simply Red',
#   'Travis Scott',
#   'Tommy',
#   'Lil Tecca',
#   'Simply Red',
#   'French Montana, Swae Lee',
#   'Simply Red',
#   'Taylor Swift',
#   'Louise',
#   'Lady Gaga',
#   'Volo',
#   'The Weeknd, Daft Punk',
#   'Tommy',
#   'Lady Gaga, Bradley Cooper',
#   'Jonny Greenwood, Thom Yorke, Philip Selway, Edward O’Brien, Colin Greenwood, VOCES8, Thomas Gould, Matthew Sharp, Eleanor Turner',
#   'The Neighbourhood',
#   'K27, Einar',
#   'Chase Atlantic',
#   'Little Big, Ruki Vverh!',
#   'Zara Larsson',
#   'Black Rain',
#   'Kendrick Lamar',
#   'Shannon & the Clams',
#   'Imagine Dragons',
#   'sana',
#   'Future, The Weeknd',
#   'Cromo',
#   'Travis Scott',
#   'Shade, Federica Carta',
#   'Kendrick Lamar, SZA',
#   'Pretty Pink, Chapeau Claque',
#   'Tyler, The Creator, Kali Uchis',
#   'Anitta, J Balvin',
#   'Lord Huron',
#   'K27, Einar',
#   'Kendrick Lamar',
#   'Jonny Greenwood, Thom Yorke, Philip Selway, Edward O’Brien, Colin Greenwood, VOCES8, Thomas Gould, Matthew Sharp, Eleanor Turner',
#   'Bruno Mars',
#   'Simply Red',
#   'The Weeknd, Daft Punk',
#   'Missy Elliott, Lamb',
#   'Taylor Swift',
#   'Alexander Stewart',
#   'Chase Atlantic',
#   'Little Big, Ruki Vverh!',
#   'The Chainsmokers, Coldplay',
#   'Simply Red',
#   'Ed Sheeran',
#   'Simply Red',
#   'Ed Sheeran',
#   'Simply Red',
#   'Frank Ocean',
#   'CAPO, Tommy',
#   'Billie Eilish, Khalid',
#   'Jula',
#   'The Chainsmokers, Halsey',
#   'Simply Red',
#   'Imagine Dragons',
#   'Geegun, MAKSIM',
#   'Travis Scott',
#   'Simply Red',
#   'Ruth B.',
#   'Rahul Raj, Suchith Sureshan',
#   'Frank Ocean',
#   'Louise',
#   'Lewis Capaldi',
#   'Simply Red',
#   'Drake, Wizkid, Kyla',
#   'Janie Bay, Early B',
#   'Lil Tecca',
#   'Tommy',
#   'The Weeknd',
#   'sana',
#   'The Weeknd',
#   'Frans, Yoel905',
#   'Daniel Caesar, H.E.R.',
#   'Tommy',
#   'Shawn Mendes',
#   'Paul van Dyk, Pierre Pienaar',
#   'Lord Huron',
#   'Simply Red',
#   'Kendrick Lamar, SZA',
#   'Jonny Greenwood, Thom Yorke, Philip Selway, Edward O’Brien, Colin Greenwood, VOCES8, Thomas Gould, Matthew Sharp, Eleanor Turner',
#   'Billie Eilish, Khalid',
#   'Alexander Stewart',
#   'Tyler, The Creator, Kali Uchis',
#   'Missy Elliott, Lamb',
#   'Lewis Capaldi',
#   'Little Big, Ruki Vverh!',
#   'Lady Gaga, Bradley Cooper',
#   'Simply Red',
#   'Billie Eilish',
#   'Simply Red',
#   'Jul',
#   'Simply Red',
#   'Ninho',
#   'Volo',
#   'Zara Larsson',
#   'Simply Red',
#   'GIMS',
#   'Simply Red',
#   'GIMS',
#   'Pretty Pink, Chapeau Claque',
#   'Ninho',
#   'Simply Red',
#   'SYML',
#   'Austin Brown',
#   'Lady Gaga',
#   'MEL, Leto',
#   'Ed Sheeran',
#   'Geegun, MAKSIM',
#   'The Chainsmokers, Coldplay',
#   'Carlos Marco, Blas Cantó',
#   'Imagine Dragons',
#   'Rahul Raj, Suchith Sureshan',
#   'Ninho',
#   'K27, Einar',
#   'Billie Eilish',
#   'Shannon & the Clams',
#   'Lost Frequencies',
#   'Grace Hodgett Young, Dónal Finn',
#   'Ed Sheeran',
#   'Lisa',
#   'Kendrick Lamar',
#   'Lisa',
#   "Jok'air",
#   'Louise',
#   'Chase Atlantic',
#   'Anitta, J Balvin',
#   'Kendrick Lamar, SZA',
#   'Jonny Greenwood, Thom Yorke, Philip Selway, Edward O’Brien, Colin Greenwood, VOCES8, Thomas Gould, Matthew Sharp, Eleanor Turner',
#   'Lord Huron',
#   'Simply Red',
#   'Ninho',
#   'Louise',
#   'Billie Eilish, Khalid',
#   'K27, Einar',
#   'Tyler, The Creator, Kali Uchis',
#   'CAPO, Tommy',
#   'The Chainsmokers, Coldplay',
#   'Simply Red',
#   'Kendrick Lamar',
#   'Alexander Stewart',
#   'GIMS',
#   'Simply Red',
#   'Lewis Capaldi',
#   'Pretty Pink, Chapeau Claque',
#   'Travis Scott',
#   'Simply Red',
#   'Taylor Swift',
#   'Anitta, J Balvin',
#   'Imagine Dragons',
#   'Missy Elliott, Lamb',
#   'Travis Scott',
#   'Little Big, Ruki Vverh!',
#   'Ed Sheeran',
#   'Simply Red',
#   'French Montana, Swae Lee',
#   'Simply Red',
#   'GIMS',
#   'Jula',
#   'The Weeknd, Daft Punk',
#   'Geegun, MAKSIM',
#   'Chase Atlantic',
#   'Simply Red',
#   'Lil Tecca',
#   'Rahul Raj, Suchith Sureshan',
#   'Ninho',
#   'Janie Bay, Early B',
#   'Lady Gaga',
#   'Tommy',
#   'Lady Gaga, Bradley Cooper',
#   'sana',
#   'Ed Sheeran',
#   'Frans, Yoel905',
#   'Frank Ocean',
#   'Tommy',
#   'Juice WRLD',
#   'Paul van Dyk, Pierre Pienaar',
#   'Kendrick Lamar, SZA',
#   'Jonny Greenwood, Thom Yorke, Philip Selway, Edward O’Brien, Colin Greenwood, VOCES8, Thomas Gould, Matthew Sharp, Eleanor Turner',
#   'Lord Huron',
#   'Simply Red',
#   'Tyler, The Creator, Kali Uchis',
#   'Missy Elliott, Lamb',
#   'Billie Eilish, Khalid',
#   'Simply Red',
#   'Broederliefde, $hirak',
#   'Simply Red',
#   'Zara Larsson',
#   'Alexander Stewart',
#   'Davina Michelle, Beste Zangers',
#   'Simply Red',
#   'Lady Gaga, Bradley Cooper',
#   'Simply Red',
#   'Jonna Fraser, Broederliefde',
#   'Simply Red',
#   'Lady Gaga',
#   'Kendrick Lamar',
#   'Lewis Capaldi',
#   'Little Big, Ruki Vverh!',
#   'Frank Ocean',
#   'Simply Red',
#   'Danny Vera',
#   'Giuseppe Verdi, Sonya Yoncheva, Massimo Zanetti, Munich Radio Orchestra',
#   'Billie Eilish',
#   'Pretty Pink, Chapeau Claque',
#   'Avicii, Sandro Cavazza',
#   'Anitta, J Balvin',
#   'The Chainsmokers, Coldplay',
#   'Konshens, King Kosa',
#   'SFB, Ronnie Flex, Lil Kleine, Bokoesam',
#   'DAWN',
#   'Ronnie Flex, Frenna',
#   'Kerim Yağcı',
#   'Niall Horan',
#   'Geegun, MAKSIM',
#   'Ed Sheeran',
#   'Michael Kiwanuka',
#   'Rihanna',
#   'Jula',
#   'Billie Eilish',
#   'Austin Brown',
#   'Mark Ronson, Bruno Mars',
#   'K27, Einar',
#   'SYML',
#   'Janie Bay, Early B',
#   'SFB, Ronnie Flex',
#   'Duncan Laurence'],
#  'pais': ['AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'AT',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'DE',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'CH',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'LI',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'BE',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'LU',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL',
#   'NL'],
#  'genero': []}

# %% [markdown]
# Llamada a API Last.FM y filtro para conseguir el género

# %%
p_central_last = requests.get(f"https://ws.audioscrobbler.com/2.0/?method=track.gettoptags&artist=Sasha&track=here+she+comes+again&api_key={API_KEY}&autocorrect=1&format=json")

# %%
p_central_last.json()['toptags']['tag'][0]['name']
# Out:
# 'pop'

# %%
lista_nombres_central = list(dic_central.values())[0]
lista_artistas_central = list(dic_central.values())[2]

# %%
def llamada_lastfm(lista_nombres, lista_artistas,datos):
    for i in range(len(lista_nombres)):
        try:
            nombre = str(lista_nombres[i]).replace(' ', '+')
            artista = lista_artistas[i].replace(' ', '+').replace(',', '+&')
            llamada_genero = requests.get(f"https://ws.audioscrobbler.com/2.0/?method=track.gettoptags&artist={artista}&track={nombre}&api_key={API_KEY}&autocorrect=1&format=json")
            try:
                genero_cancion = llamada_genero.json()['toptags']['tag'][0]['name']
                datos['genero'].append(genero_cancion)
            except KeyError:
                datos['genero'].append("NULL")
                print(f"La canción {lista_nombres[i]} no está registrada en lastfm")
                
            except IndexError:
                datos['genero'].append("NULL")
                print(f"La canción {lista_nombres[i]} no tiene tags")
            
        except:
            datos['genero'].append("NULL")
            print(f"Hay problemas con la cación {lista_nombres[i]}")

# %%
llamada_lastfm(lista_nombres_central, lista_artistas_central, dic_central)
# Out:
# La canción All The Stars (with SZA) no está registrada en lastfm
# La canción Say You Love Me (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción Liebe Grüße (mit Fatoni) no está registrada en lastfm
# La canción Neymar no está registrada en lastfm
# La canción I'm Better (feat. Lamb) no está registrada en lastfm
# La canción Matador (feat. Tommy) no está registrada en lastfm
# La canción Holding Back the Years (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción Greenwood, Philip Selway, Edward O'Brien, Colin Greenwood: Pyramid Song (Arr. Lawson) no está registrada en lastfm
# La canción Ohne mein Team no está registrada en lastfm
# La canción So Beautiful (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción Durch die schweren Zeiten (I'll Carry You) [feat. Angus & Julia Stone] [MTV Unplugged 2] - Live vom Atlantik 2018 no está registrada en lastfm
# La canción See You Again (feat. Kali Uchis) no está registrada en lastfm
# La canción Your Mirror (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción Something Just Like This no está registrada en lastfm
# La canción A New Flame (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción Pakete no tiene tags
# La canción Falling Down - Bonus Track no está registrada en lastfm
# La canción Слэмятся пацаны no está registrada en lastfm
# La canción For Your Babies (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción lovely (with Khalid) no está registrada en lastfm
# La canción Auffe aufn Berg no está registrada en lastfm
# La canción Someday in My Life (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción Sirenen no tiene tags
# La canción Wenn jetzt Sommer wär (feat. Chapeau Claque) no está registrada en lastfm
# La canción Hate to Love (feat. Jamie T) no está registrada en lastfm
# La canción Evergreen no está registrada en lastfm
# La canción Medusa no tiene tags
# La canción Full Automatic (feat. Diego) no está registrada en lastfm
# La canción Unforgettable no está registrada en lastfm
# La canción Did You Love Me no está registrada en lastfm
# La canción Without You (feat. Sandro Cavazza) no está registrada en lastfm
# La canción Дождь (feat. МакSим) no está registrada en lastfm
# La canción Starboy no está registrada en lastfm
# La canción O secunda no está registrada en lastfm
# La canción Happy End no tiene tags
# La canción All The Stars (with SZA) no está registrada en lastfm
# La canción Matador (feat. Tommy) no está registrada en lastfm
# La canción Babyschlaf mit Meeresrauschen no tiene tags
# La canción Дождь (feat. МакSим) no está registrada en lastfm
# La canción Nie mehr Fastelovend no tiene tags
# La canción Liebe Grüße (mit Fatoni) no está registrada en lastfm
# La canción Слэмятся пацаны no está registrada en lastfm
# La canción I'm Better (feat. Lamb) no está registrada en lastfm
# La canción Guten Morgen Barbarossaplatz no tiene tags
# La canción Sirenen no tiene tags
# La canción Neymar no está registrada en lastfm
# La canción Wenn jetzt Sommer wär (feat. Chapeau Claque) no está registrada en lastfm
# La canción Holding Back the Years (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción Greenwood, Philip Selway, Edward O'Brien, Colin Greenwood: Pyramid Song (Arr. Lawson) no está registrada en lastfm
# La canción Pakete no tiene tags
# La canción Falling Down - Bonus Track no está registrada en lastfm
# La canción Stronger Together no está registrada en lastfm
# La canción So Beautiful (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción lovely (with Khalid) no está registrada en lastfm
# La canción Say You Love Me (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción Ohne mein Team no está registrada en lastfm
# La canción Kapitel 1 / Frühling no está registrada en lastfm
# La canción For Your Babies (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción Happy End no tiene tags
# La canción Your Mirror (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción Bester Sommer no tiene tags
# La canción See You Again (feat. Kali Uchis) no está registrada en lastfm
# La canción Hate to Love (feat. Jamie T) no está registrada en lastfm
# La canción Unforgettable no está registrada en lastfm
# La canción Someday in My Life (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción Starboy no está registrada en lastfm
# La canción Medusa no tiene tags
# La canción A New Flame (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción Something Just Like This no está registrada en lastfm
# La canción All The Stars (with SZA) no está registrada en lastfm
# La canción Wenn jetzt Sommer wär (feat. Chapeau Claque) no está registrada en lastfm
# La canción I'm Better (feat. Lamb) no está registrada en lastfm
# La canción Liebe Grüße (mit Fatoni) no está registrada en lastfm
# La canción lovely (with Khalid) no está registrada en lastfm
# La canción Matador (feat. Tommy) no está registrada en lastfm
# La canción Something Just Like This no está registrada en lastfm
# La canción Holding Back the Years (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción Дождь (feat. МакSим) no está registrada en lastfm
# La canción See You Again (feat. Kali Uchis) no está registrada en lastfm
# La canción A New Flame (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción Your Mirror (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción For Your Babies (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción Someday in My Life (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción Pakete no tiene tags
# La canción Say You Love Me (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción Unforgettable no está registrada en lastfm
# La canción So Beautiful (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción Tabarnak no tiene tags
# La canción Starboy no está registrada en lastfm
# La canción Sirenen no tiene tags
# La canción Shallow no está registrada en lastfm
# La canción Greenwood, Philip Selway, Edward O'Brien, Colin Greenwood: Pyramid Song (Arr. Lawson) no está registrada en lastfm
# La canción Skrrt no está registrada en lastfm
# La canción Слэмятся пацаны no está registrada en lastfm
# La canción Killing Me no tiene tags
# La canción Did You Love Me no está registrada en lastfm
# La canción Low Life (feat. The Weeknd) no está registrada en lastfm
# La canción Cristo no tiene tags
# La canción Senza farlo apposta no está registrada en lastfm
# La canción All The Stars (with SZA) no está registrada en lastfm
# La canción Wenn jetzt Sommer wär (feat. Chapeau Claque) no está registrada en lastfm
# La canción See You Again (feat. Kali Uchis) no está registrada en lastfm
# La canción Downtown no está registrada en lastfm
# La canción Skrrt no está registrada en lastfm
# La canción Greenwood, Philip Selway, Edward O'Brien, Colin Greenwood: Pyramid Song (Arr. Lawson) no está registrada en lastfm
# La canción Holding Back the Years (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción Starboy no está registrada en lastfm
# La canción I'm Better (feat. Lamb) no está registrada en lastfm
# La canción Слэмятся пацаны no está registrada en lastfm
# La canción Something Just Like This no está registrada en lastfm
# La canción Say You Love Me (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción For Your Babies (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción So Beautiful (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción Pink + White no tiene tags
# La canción Matador (feat. Tommy) no está registrada en lastfm
# La canción lovely (with Khalid) no está registrada en lastfm
# La canción Closer no está registrada en lastfm
# La canción Your Mirror (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción Дождь (feat. МакSим) no está registrada en lastfm
# La canción Someday in My Life (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción Ee Khalbitha (From "IDI") no está registrada en lastfm
# La canción A New Flame (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción One Dance no está registrada en lastfm
# La canción Die Heelal (feat. Early B) no está registrada en lastfm
# La canción Sirenen no tiene tags
# La canción Do It Like You Mean It (feat. Yoel 905) no está registrada en lastfm
# La canción Best Part (feat. H.E.R.) no está registrada en lastfm
# La canción Pakete no tiene tags
# La canción Stronger Together no está registrada en lastfm
# La canción Holding Back the Years (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción All The Stars (with SZA) no está registrada en lastfm
# La canción Greenwood, Philip Selway, Edward O'Brien, Colin Greenwood: Pyramid Song (Arr. Lawson) no está registrada en lastfm
# La canción lovely (with Khalid) no está registrada en lastfm
# La canción See You Again (feat. Kali Uchis) no está registrada en lastfm
# La canción I'm Better (feat. Lamb) no está registrada en lastfm
# La canción Слэмятся пацаны no está registrada en lastfm
# La canción Shallow no está registrada en lastfm
# La canción Your Mirror (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción So Beautiful (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción Sous la lune no tiene tags
# La canción Say You Love Me (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción La vie qu'on mène no tiene tags
# La canción Tabarnak no tiene tags
# La canción For Your Babies (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción Someday in My Life (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción Où aller no tiene tags
# La canción Wenn jetzt Sommer wär (feat. Chapeau Claque) no está registrada en lastfm
# La canción Vrais no tiene tags
# La canción A New Flame (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción In Betweenin' no tiene tags
# La canción Allez (feat. Leto) no está registrada en lastfm
# La canción Дождь (feat. МакSим) no está registrada en lastfm
# La canción Something Just Like This no está registrada en lastfm
# La canción Even Angels (feat. Blas Cantó) no está registrada en lastfm
# La canción Ee Khalbitha (From "IDI") no está registrada en lastfm
# La canción Putana no tiene tags
# La canción Skrrt no está registrada en lastfm
# La canción Did You Love Me no está registrada en lastfm
# La canción All I've Ever Known no está registrada en lastfm
# La canción Slow Songs no tiene tags
# La canción Strangers With A Memory no tiene tags
# La canción Big Daddy Jok no tiene tags
# La canción Downtown no está registrada en lastfm
# La canción All The Stars (with SZA) no está registrada en lastfm
# La canción Greenwood, Philip Selway, Edward O'Brien, Colin Greenwood: Pyramid Song (Arr. Lawson) no está registrada en lastfm
# La canción A New Flame (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción La vie qu'on mène no tiene tags
# La canción lovely (with Khalid) no está registrada en lastfm
# La canción Skrrt no está registrada en lastfm
# La canción See You Again (feat. Kali Uchis) no está registrada en lastfm
# La canción Matador (feat. Tommy) no está registrada en lastfm
# La canción Something Just Like This no está registrada en lastfm
# La canción Your Mirror (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción Holding Back the Years (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción Wenn jetzt Sommer wär (feat. Chapeau Claque) no está registrada en lastfm
# La canción For Your Babies (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción Downtown no está registrada en lastfm
# La canción I'm Better (feat. Lamb) no está registrada en lastfm
# La canción Слэмятся пацаны no está registrada en lastfm
# La canción Say You Love Me (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción Unforgettable no está registrada en lastfm
# La canción So Beautiful (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción Où aller no tiene tags
# La canción Starboy no está registrada en lastfm
# La canción Дождь (feat. МакSим) no está registrada en lastfm
# La canción Someday in My Life (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción Ee Khalbitha (From "IDI") no está registrada en lastfm
# La canción Vrais no tiene tags
# La canción Die Heelal (feat. Early B) no está registrada en lastfm
# La canción Sirenen no tiene tags
# La canción Shallow no está registrada en lastfm
# La canción Do It Like You Mean It (feat. Yoel 905) no está registrada en lastfm
# La canción Pink + White no tiene tags
# La canción Pakete no tiene tags
# La canción Stronger Together no está registrada en lastfm
# La canción All The Stars (with SZA) no está registrada en lastfm
# La canción Greenwood, Philip Selway, Edward O'Brien, Colin Greenwood: Pyramid Song (Arr. Lawson) no está registrada en lastfm
# La canción Holding Back the Years (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción See You Again (feat. Kali Uchis) no está registrada en lastfm
# La canción I'm Better (feat. Lamb) no está registrada en lastfm
# La canción lovely (with Khalid) no está registrada en lastfm
# La canción So Beautiful (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción Jungle no está registrada en lastfm
# La canción Say You Love Me (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción Duurt Te Lang no está registrada en lastfm
# La canción Your Mirror (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción Shallow no está registrada en lastfm
# La canción For Your Babies (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción Do Or Die no está registrada en lastfm
# La canción Someday in My Life (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción God Is Gangsta no tiene tags
# La canción Слэмятся пацаны no está registrada en lastfm
# La canción Pink + White no tiene tags
# La canción A New Flame (Live at Ziggo Dome, Amsterdam) no tiene tags
# La canción Verdi: Il Trovatore - Tacea la notte placida no está registrada en lastfm
# La canción Wenn jetzt Sommer wär (feat. Chapeau Claque) no está registrada en lastfm
# La canción Without You (feat. Sandro Cavazza) no está registrada en lastfm
# La canción Downtown no está registrada en lastfm
# La canción Something Just Like This no está registrada en lastfm
# La canción In My Sleep (feat. King Kosa) no está registrada en lastfm
# La canción Investeren In De Liefde no está registrada en lastfm
# La canción Wake Up (A Fashion Film) no tiene tags
# La canción Energie no está registrada en lastfm
# La canción Gönlüm Ataşlara Yandı no tiene tags
# La canción Дождь (feat. МакSим) no está registrada en lastfm
# La canción Cold Little Heart - Live Session no tiene tags
# La canción In Betweenin' no tiene tags
# La canción Uptown Funk (feat. Bruno Mars) no está registrada en lastfm
# La canción Skrrt no está registrada en lastfm
# La canción Die Heelal (feat. Early B) no está registrada en lastfm
# La canción Lovely Body no está registrada en lastfm
# La canción Arcade - 1 Mic 1 Take no tiene tags

# %%
df_central = pd.DataFrame(dic_central)

# %%
df_central.index.name="id"

# %%
df_central
# Out:
#                                               nombre  popularity  \
# id
# 0                           All The Stars (with SZA)          90
# 1    Say You Love Me (Live at Ziggo Dome, Amsterdam)           1
# 2                                   The Night We Met          85
# 3                           Liebe Grüße (mit Fatoni)           0
# 4                                             Neymar          63
# ..                                               ...         ...
# 345                                            Skrrt           7
# 346                                  Where's My Love          76
# 347                       Die Heelal (feat. Early B)           0
# 348                                      Lovely Body          53
# 349                            Arcade - 1 Mic 1 Take           0
#
#                     artista pais     genero
# id
# 0       Kendrick Lamar, SZA   AT       NULL
# 1                Simply Red   AT       NULL
# 2                Lord Huron   AT      indie
# 3    Antilopen Gang, Fatoni   AT       NULL
# 4       Capital Bra, Ufo361   AT       NULL
# ..                      ...  ...        ...
# 345              K27, Einar   NL       NULL
# 346                    SYML   NL  teen wolf
# 347      Janie Bay, Early B   NL       NULL
# 348        SFB, Ronnie Flex   NL       NULL
# 349         Duncan Laurence   NL       NULL
#
# [350 rows x 5 columns]

# %%
df_central.to_csv("paises_centrales_2015_2019.csv")
