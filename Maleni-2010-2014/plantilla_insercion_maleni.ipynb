# %% [markdown]
# # 🛜 Set-up para la conexión entre mysql y python 🛜

# %%
import json
import pandas as pd
import mysql.connector
from mysql.connector import errorcode

# %% [markdown]
# 1. Nos conectamos a la base de datos (script de creación en _schema_bbdd.sql_)

# %%
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
host='127.0.0.1',
database='musicstream', 
auth_plugin ='mysql_native_password')

# %% [markdown]
# 2. Creamos el cursor

# %%
mycursor = cnx.cursor()

# %% [markdown]
# # 🏗️ Añadiendo datos desde los ficheros .csv 🏗️

# %% [markdown]
# ### Añadimos los datos a la tabla zonas

# %%
query = "INSERT INTO zonas(nombre_zona) VALUES(%s)"
val = [[('mediterraneo')], [('norte')], [('centro')], [('este')]]
mycursor.executemany(query, val)
cnx.commit()

# %% [markdown]
# ### Añadimos los datos a la tabla países

# %% [markdown]
# 1. Definimos los diccionarios con los paises para cada zona

# %%
paises_mediterraneos = {
    "ES": "España",
    "FR": "Francia",
    "MC": "Mónaco",
    "IT": "Italia",
    "SI": "Eslovenia",
    "HR": "Croacia",
    "BA": "Bosnia y Herzegovina",
    "ME": "Montenegro",
    "AL": "Albania",
    "GR": "Grecia",
    "MT": "Malta",
    "CY": "Chipre"}
paises_este_europa = {
    "BY": "Bielorrusia",
    "BG": "Bulgaria",
    "CZ": "Chequia",
    "SK": "Eslovaquia",
    "HU": "Hungría",
    "MD": "Moldavia",
    "PL": "Polonia",
    "RO": "Rumanía",
    "UA": "Ucrania"}
paises_norte_europa = {
    "DK": "Dinamarca",
    "EE": "Estonia",
    "FI": "Finlandia",
    "IS": "Islandia",
    "IE": "Irlanda",
    "LT": "Lituania",
    "LV": "Letonia",
    "NO": "Noruega",
    "SE": "Suecia",
    "GB": "Reino Unido"}
paises_europa_central = {
    "AT": "Austria",
    "DE": "Alemania",
    "CH": "Suiza",
    "LI": "Liechtenstein",
    "BE": "Bélgica",
    "LU": "Luxemburgo",
    "NL": "Países Bajos"}

# %% [markdown]
# 2. Definimos la función `añadir_pais`

# %%
def añadir_pais(diccionario, id_zona):
    ''' Añade datos a la tabla de paises.

        Args: 
            diccionario (dict): Un diccionario de los definidos para cada zona donde se recogen los países y sus códigos.
            id_zona (int): Número asignado a cada zona de europa en la tabla zonas. 

    '''
    for id, pais in diccionario.items():
        query = "INSERT INTO paises(id_pais, nombre_pais, id_zona) VALUES(%s, %s, %s)"
        val = [(id, pais, id_zona)] 
        mycursor.executemany(query, val)
        cnx.commit()

# %% [markdown]
# Los id_zona quedan entonces como:
# - 1 mediterraneo
# - 2 norte
# - 3 centro
# - 4 este

# %% [markdown]
# 3. Llamamos a la función en bucle para añadir los países de cada zona de una sola vez.

# %%
# Definimos estas dos listas, que nos van a servir para poder llamar en bucle a la función. Es MUY IMPORTANTE el orden, debe coincidir el nombre del diccionario con el id_zona asignado a cada zona.
lista_diccionarios = [paises_mediterraneos, paises_norte_europa, paises_europa_central, paises_este_europa]
lista_zonas = [i for i in range(1,5)]

# %%
for i in range(len(lista_diccionarios)):
    añadir_pais(lista_diccionarios[i], lista_zonas[i])

# %% [markdown]
# ### Añadimos los datos a la tabla años

# %%
query_años = "INSERT INTO años(rango_años) VALUES(%s)"
val_años = [[('2000-2004')], [('2005-2009')], [('2010-2014')], [('2015-2019')], [('2020-2024')]]
mycursor.executemany(query_años, val_años)
cnx.commit()

# %% [markdown]
# ### Añadimos los datos a la tabla artistas

# %% [markdown]
# 1. Definimos la función `convertir_csv`, que convierte cada uno de los csv que hemos creado en un DataFrame.

# %%
def convertir_csv(zona, años):
    ''' Convierte el csv de cada zona y rango de años en un DataFrame.
    
        Args:
            zona (str): Nombre de la zona.
            años (str): Rango de años en la forma añoinicio_añofin. 
    '''
    df = pd.read_csv(f'archivos_csv/paises_{zona}_{años}.csv',index_col = 0)
    return df

# %% [markdown]
# 2. Llamamos a la función una vez por cada csv que debemos convertir.

# %%
# Definimos estas dos listas, que nos van a servir para poder llamar a la función.
lista_nombre_zona = ["este_europa", "europa_central", "mediterraneos", "norte_europa"]
lista_años = ["2000_2004", "2005_2009", "2010_2014", "2015_2019", "2020_2024"]

# %%
# Países del este
df_este_2000_2004 = convertir_csv(lista_nombre_zona[0], lista_años[0])
df_este_2005_2009 = convertir_csv(lista_nombre_zona[0], lista_años[1])
df_este_2010_2014 = convertir_csv(lista_nombre_zona[0], lista_años[2])
df_este_2015_2019 = convertir_csv(lista_nombre_zona[0], lista_años[3])
df_este_2020_2024 = convertir_csv(lista_nombre_zona[0], lista_años[4])

# %%
# Países del centro
df_centro_2000_2004 = convertir_csv(lista_nombre_zona[1], lista_años[0])
df_centro_2005_2009 = convertir_csv(lista_nombre_zona[1], lista_años[1])
df_centro_2010_2014 = convertir_csv(lista_nombre_zona[1], lista_años[2])
df_centro_2015_2019 = convertir_csv(lista_nombre_zona[1], lista_años[3])
df_centro_2020_2024 = convertir_csv(lista_nombre_zona[1], lista_años[4])

# %%
# Países mediterráneos
df_medit_2000_2004 = convertir_csv(lista_nombre_zona[2], lista_años[0])
df_medit_2005_2009 = convertir_csv(lista_nombre_zona[2], lista_años[1])
df_medit_2010_2014 = convertir_csv(lista_nombre_zona[2], lista_años[2])
df_medit_2015_2019 = convertir_csv(lista_nombre_zona[2], lista_años[3])
df_medit_2020_2024 = convertir_csv(lista_nombre_zona[2], lista_años[4])

# %%
# Países del norte
df_norte_2000_2004 = convertir_csv(lista_nombre_zona[3], lista_años[0])
df_norte_2005_2009 = convertir_csv(lista_nombre_zona[3], lista_años[1])
df_norte_2010_2014 = convertir_csv(lista_nombre_zona[3], lista_años[2])
df_norte_2015_2019 = convertir_csv(lista_nombre_zona[3], lista_años[3])
df_norte_2020_2024 = convertir_csv(lista_nombre_zona[3], lista_años[4])

# %%
lista_df_csv = [df_este_2000_2004, df_este_2005_2009, df_este_2010_2014, df_este_2015_2019, df_este_2020_2024, df_centro_2000_2004, df_centro_2005_2009, df_centro_2010_2014,
                df_centro_2015_2019, df_centro_2020_2024, df_medit_2000_2004, df_medit_2005_2009, df_medit_2010_2014, df_medit_2015_2019, df_medit_2020_2024,df_norte_2000_2004,
                df_norte_2005_2009, df_norte_2010_2014, df_norte_2015_2019, df_norte_2020_2024]

# %%
# lista_df_ordenados = []
# for l in lista_df_csv:
    var = l.sort_values(['popularity'], axis=0, ascending=False, ignore_index=True)[0:50]
    lista_df_ordenados.append(var)

# %% [markdown]
# 3. Creamos una lista de artistas vacía y luego un DataFrame con todos los artistas por zona.

# %%
artistas = []
df_mediterraneo = pd.concat(
    [df_medit_2000_2004['artista'], df_medit_2005_2009['artista'], df_medit_2010_2014['artista'], df_medit_2015_2019['artista'], df_medit_2020_2024['artista']],
    axis=1,
    keys=["00-04", "05-09", "10-14", "15-19", "20-24"])
df_este = pd.concat(
    [df_este_2000_2004['artista'], df_este_2005_2009['artista'], df_este_2010_2014['artista'], df_este_2015_2019['artista'], df_este_2020_2024['artista']],
    axis=1,
    keys=["00-04", "05-09", "10-14", "15-19", "20-24"])
df_centro = pd.concat(
    [df_centro_2000_2004['artista'], df_centro_2005_2009['artista'], df_centro_2010_2014['artista'], df_centro_2015_2019['artista'], df_centro_2020_2024['artista']],
    axis=1,
    keys=["00-04", "05-09", "10-14", "15-19", "20-24"])
df_norte = pd.concat(
    [df_norte_2000_2004['artista'], df_norte_2005_2009['artista'], df_norte_2010_2014['artista'], df_norte_2015_2019['artista'], df_norte_2020_2024['artista']],
    axis=1,
    keys=["00-04", "05-09", "10-14", "15-19", "20-24"])

# %%
# Esta lista es para poder meter los datos de los df en bucle.
lista_df = [df_mediterraneo, df_este, df_centro, df_norte]

# %% [markdown]
# 4. Con el siguiente bucle, convertimos cada artista en una lista y lo añadimos a la lista artistas.

# %%
for df in lista_df:
    for i in df.itertuples(name=None, index=False):
        for n in range(4):
            if ([i[n]]) not in artistas:
                artistas.append(([i[n]]))

# %%
len(artistas)
# Out:
# 981

# %% [markdown]
# 5. Ejecutamos la inserción

# %%
query_artistas = "INSERT INTO artistas(nombre_artista) VALUES(%s)"
for artista in artistas:
    try:
     mycursor.execute(query_artistas, artista)
     cnx.commit()
    except:
      continue
cnx.close()

# %% [markdown]
# ### Añadimos los datos a la tabla canciones

# %% [markdown]
# Recordemos los id_lustro para cada conjunto de 5 años:
# - 1 = 2000-2004
# - 2 = 2005-2009
# - 3 = 2010-2014
# - 4 = 2015-2019
# - 5 = 2020-2024

# %% [markdown]
# Volvemos a abrir la conexión y a definir el cursor

# %%
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab', host='127.0.0.1',
                                    database='musicstream', 
                                    auth_plugin ='mysql_native_password')
mycursor = cnx.cursor()

# %% [markdown]
# Hay algunos datos que son `NaN`, y MySQL no los reconoce, por lo que hay que convertirlos a None.
#
# Para ello, creamos la función `eliminar_nan`

# %%
def eliminar_nan (df):
    df_limpio = df.replace({float('NaN'): None})
    return df_limpio

# %% [markdown]
# Limpiamos los df y lo metemos en la lista `lista_df_limpios`

# %% [markdown]
# ## Aqui he cambiado lo de df_ordenados por lista_df_csv

# %%
lista_df_limpios = []

for data in lista_df_csv:
    df_limpio = eliminar_nan(data)
    lista_df_limpios.append(df_limpio)

# %% [markdown]
# Definimos una función para insertar las canciones

# %%
def insertar_canciones (df):
    lista_querys = []
    for i in range(len(df)):
        tupla_insercion = (str(df['nombre'][i]), str(df['genero'][i]), int(df['popularity'][i]))
        lista_querys.append(tupla_insercion)
    return lista_querys

# %% [markdown]
# Creamos la lista de tuplas para insertar, descartando aquellas canciones que coinciden en todos los campos.

# %%
lista_de_tuplas = []

for df in lista_df_limpios:    
    tuplas = insertar_canciones(df)
    for t in tuplas:
        if t not in lista_de_tuplas:
            lista_de_tuplas.append(t)

# %% [markdown]
# Definimos la query canciones:

# %%
query_canciones = "INSERT INTO canciones(cancion, genero, popularidad) VALUES(%s, %s, %s)"

# %%
mycursor.executemany(query_canciones, lista_de_tuplas)
cnx.commit()

# %%
cnx.close()

# %% [markdown]
# ### Añadimos los datos a las tablas intermedias

# %% [markdown]
# Primero, pais en cancion:

# %%
contador = 0
queries_pais_cancion = []
for t in lista_de_tuplas:
    contador += 1
    for df in lista_df_limpios:
        for i in range(len(df)):
            if df['nombre'][i] in t:
                tupla_pais_cancion = (df['pais'][i], contador)
                queries_pais_cancion.append(tupla_pais_cancion)

# %%
query_pais_en_cancion = "INSERT INTO pais_en_cancion(id_pais, id_cancion) VALUES(%s, %s)"

# %%
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab', host='127.0.0.1',
                                    database='musicstream', 
                                    auth_plugin ='mysql_native_password')
mycursor = cnx.cursor()

# %%
for q in queries_pais_cancion:
    try:
        mycursor.execute(query_pais_en_cancion, q)
        cnx.commit()
    except:
        print(f"La entrada {q} está repetida")
# Out:
# La entrada ('SE', 219) está repetida
# La entrada ('CZ', 222) está repetida
# La entrada ('DE', 222) está repetida
# La entrada ('CH', 222) está repetida
# La entrada ('BY', 659) está repetida
# La entrada ('BY', 659) está repetida
# La entrada ('BY', 659) está repetida
# La entrada ('RO', 659) está repetida
# La entrada ('RO', 659) está repetida
# La entrada ('RO', 659) está repetida
# La entrada ('BY', 661) está repetida
# La entrada ('BY', 661) está repetida
# La entrada ('BY', 661) está repetida
# La entrada ('RO', 661) está repetida
# La entrada ('RO', 661) está repetida
# La entrada ('RO', 661) está repetida
# La entrada ('BY', 667) está repetida
# La entrada ('BY', 667) está repetida
# La entrada ('BY', 672) está repetida
# La entrada ('BY', 672) está repetida
# La entrada ('BY', 674) está repetida
# La entrada ('BY', 674) está repetida
# La entrada ('BY', 692) está repetida
# La entrada ('BY', 699) está repetida
# La entrada ('MT', 712) está repetida
# La entrada ('AT', 749) está repetida
# La entrada ('CH', 749) está repetida
# La entrada ('LI', 749) está repetida
# La entrada ('LU', 749) está repetida
# La entrada ('MC', 749) está repetida
# La entrada ('BA', 749) está repetida
# La entrada ('ME', 749) está repetida
# La entrada ('AL', 749) está repetida
# La entrada ('MT', 749) está repetida
# La entrada ('NO', 749) está repetida
# La entrada ('PL', 842) está repetida
# La entrada ('PL', 851) está repetida
# La entrada ('BE', 855) está repetida
# La entrada ('MT', 855) está repetida
# La entrada ('IE', 855) está repetida
# La entrada ('NO', 855) está repetida
# La entrada ('GB', 855) está repetida
# La entrada ('SE', 939) está repetida
# La entrada ('NL', 981) está repetida
# La entrada ('NL', 1037) está repetida
# La entrada ('AT', 1124) está repetida
# La entrada ('DE', 1124) está repetida
# La entrada ('AT', 1137) está repetida
# La entrada ('CH', 1137) está repetida
# La entrada ('LI', 1137) está repetida
# La entrada ('LU', 1137) está repetida
# La entrada ('MC', 1137) está repetida
# La entrada ('BA', 1137) está repetida
# La entrada ('ME', 1137) está repetida
# La entrada ('AL', 1137) está repetida
# La entrada ('MT', 1137) está repetida
# La entrada ('NO', 1137) está repetida
# La entrada ('LI', 1158) está repetida
# La entrada ('MC', 1158) está repetida
# La entrada ('BA', 1158) está repetida
# La entrada ('ME', 1158) está repetida
# La entrada ('AL', 1158) está repetida
# La entrada ('LI', 1159) está repetida
# La entrada ('MC', 1159) está repetida
# La entrada ('BA', 1159) está repetida
# La entrada ('ME', 1159) está repetida
# La entrada ('AL', 1159) está repetida
# La entrada ('BE', 1172) está repetida
# La entrada ('FR', 1172) está repetida
# La entrada ('BE', 1178) está repetida
# La entrada ('MT', 1178) está repetida
# La entrada ('IE', 1178) está repetida
# La entrada ('NO', 1178) está repetida
# La entrada ('GB', 1178) está repetida
# La entrada ('BE', 1179) está repetida
# La entrada ('FR', 1179) está repetida
# La entrada ('HR', 1253) está repetida
# La entrada ('HR', 1332) está repetida
# La entrada ('MT', 1577) está repetida
# La entrada ('ES', 1584) está repetida
# La entrada ('ES', 1585) está repetida
# La entrada ('FR', 1613) está repetida
# La entrada ('FR', 1620) está repetida
# La entrada ('IS', 1781) está repetida
# La entrada ('IS', 1787) está repetida
# La entrada ('SE', 1788) está repetida
# La entrada ('IS', 1855) está repetida
# La entrada ('IS', 1865) está repetida
# La entrada ('SE', 1895) está repetida
# La entrada ('SE', 1991) está repetida
# La entrada ('SE', 1991) está repetida
# La entrada ('SE', 2131) está repetida
# La entrada ('SE', 2132) está repetida
# La entrada ('SE', 2132) está repetida

# %%
cnx.close()

# %% [markdown]
# Ahora, lo mismo con artista en cancion:

# %%
queries_artista_cancion = []
for t in lista_de_tuplas:
    for df in lista_df_limpios:
        for i in range(len(df)):
            if df['nombre'][i] in t:
                q_id_artista = f"SELECT id_artista FROM artistas WHERE nombre_artista = '{df['artista'][i]}';"
                q_id_cancion = f"SELECT id_cancion FROM canciones WHERE cancion = '{df['nombre'][i]}';"
                
            mycursor.execute(q_id_artista)
            id_artista = mycursor.fetchone()[0]
            mycursor.execute(q_id_cancion)
            id_cancion = mycursor.fetchone()[0]
            query = (id_artista, id_cancion)
            queries_artista_cancion.append(query)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\Usuario\anaconda3\Lib\site-packages\mysql\connector\connection_cext.py:755, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     754         query = query.encode("utf-8")
# --> 755     self._cmysql.query(
#     756         query,
#     757         raw=raw,
#     758         buffered=buffered,
#     759         raw_as_string=raw_as_string,
#     760         query_attrs=self.query_attrs,
#     761     )
#     762 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 's Cut'' at line 1
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[70], line 11
#       9 mycursor.execute(q_id_artista)
#      10 id_artista = mycursor.fetchone()[0]
# ---> 11 mycursor.execute(q_id_cancion)
#      12 id_cancion = mycursor.fetchone()[0]
#      13 query = (id_artista, id_cancion)
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\mysql\connector\cursor_cext.py:351, in CMySQLCursor.execute(self, operation, params, map_results)
#     343 self._executed = (
#     344     self._stmt_partition["single_stmts"].popleft()
#     345     if map_results
#     346     else self._stmt_partition["mappable_stmt"]
#     347 )
#     349 try:
#     350     self._handle_result(
# --> 351         self._connection.cmd_query(
#     352             self._stmt_partition["mappable_stmt"],
#     353             raw=self._raw,
#     354             buffered=self._buffered,
#     355             raw_as_string=self._raw_as_string,
#     356         )
#     357     )
#     358 except MySQLInterfaceError as err:
#     359     raise get_mysql_exception(
#     360         msg=err.msg, errno=err.errno, sqlstate=err.sqlstate
#     361     ) from err
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\mysql\connector\opentelemetry\context_propagation.py:97, in with_context_propagation.<locals>.wrapper(cnx, *args, **kwargs)
#      95 # pylint: disable=possibly-used-before-assignment
#      96 if not OTEL_ENABLED or not cnx.otel_context_propagation:
# ---> 97     return method(cnx, *args, **kwargs)
#      99 current_span = trace.get_current_span()
#     100 tp_header = None
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\mysql\connector\connection_cext.py:763, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     755     self._cmysql.query(
#     756         query,
#     757         raw=raw,
#    (...)
#     760         query_attrs=self.query_attrs,
#     761     )
#     762 except MySQLInterfaceError as err:
# --> 763     raise get_mysql_exception(
#     764         err.errno, msg=err.msg, sqlstate=err.sqlstate
#     765     ) from err
#     766 except AttributeError as err:
#     767     addr = (
#     768         self._unix_socket if self._unix_socket else f"{self._host}:{self._port}"
#     769     )
#
# ProgrammingError: 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 's Cut'' at line 1

# %%
queries_artista_cancion
# Out:
# [(464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  (464, 1),
#  ...]

# %%
info_artistas = f"SELECT id_artista FROM artistas WHERE nombre_artista = '{lista_df_limpios[0]['artista'][0]}';"

# %%
info_canciones = f"SELECT id_artista FROM artistas WHERE cancion = '{lista_df_limpios[0]['nombre'][0]}' AND id_lustro;"

# %%
mycursor.execute(info_canciones)
x = mycursor.fetchone()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\Usuario\anaconda3\Lib\site-packages\mysql\connector\connection_cext.py:755, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     754         query = query.encode("utf-8")
# --> 755     self._cmysql.query(
#     756         query,
#     757         raw=raw,
#     758         buffered=buffered,
#     759         raw_as_string=raw_as_string,
#     760         query_attrs=self.query_attrs,
#     761     )
#     762 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Unknown column 'cancion' in 'where clause'
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 mycursor.execute(info_canciones)
#       2 x = mycursor.fetchone()
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\mysql\connector\cursor_cext.py:351, in CMySQLCursor.execute(self, operation, params, map_results)
#     343 self._executed = (
#     344     self._stmt_partition["single_stmts"].popleft()
#     345     if map_results
#     346     else self._stmt_partition["mappable_stmt"]
#     347 )
#     349 try:
#     350     self._handle_result(
# --> 351         self._connection.cmd_query(
#     352             self._stmt_partition["mappable_stmt"],
#     353             raw=self._raw,
#     354             buffered=self._buffered,
#     355             raw_as_string=self._raw_as_string,
#     356         )
#     357     )
#     358 except MySQLInterfaceError as err:
#     359     raise get_mysql_exception(
#     360         msg=err.msg, errno=err.errno, sqlstate=err.sqlstate
#     361     ) from err
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\mysql\connector\opentelemetry\context_propagation.py:97, in with_context_propagation.<locals>.wrapper(cnx, *args, **kwargs)
#      95 # pylint: disable=possibly-used-before-assignment
#      96 if not OTEL_ENABLED or not cnx.otel_context_propagation:
# ---> 97     return method(cnx, *args, **kwargs)
#      99 current_span = trace.get_current_span()
#     100 tp_header = None
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\mysql\connector\connection_cext.py:763, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     755     self._cmysql.query(
#     756         query,
#     757         raw=raw,
#    (...)
#     760         query_attrs=self.query_attrs,
#     761     )
#     762 except MySQLInterfaceError as err:
# --> 763     raise get_mysql_exception(
#     764         err.errno, msg=err.msg, sqlstate=err.sqlstate
#     765     ) from err
#     766 except AttributeError as err:
#     767     addr = (
#     768         self._unix_socket if self._unix_socket else f"{self._host}:{self._port}"
#     769     )
#
# ProgrammingError: 1054 (42S22): Unknown column 'cancion' in 'where clause'

# %%
x
# Out:
# 20

# %% [markdown]
# Por último ,metemos lustro en cancion:
